# %%
import clickhouse_connect

client = clickhouse_connect.get_client(
    host="clickhouse",
    port=8123,
    username="mewroo",
    password="mewroo",
    database="default",
)

client.command("SELECT version()")
# Out:
# '25.8.14.17'

# %%
client.query("SHOW TABLES FROM finance_yf").result_rows
# Out:
# [('dim_industry',),
#  ('dim_ticker',),
#  ('fact_market_cap',),
#  ('fact_stock_prices',),
#  ('industry_membership',),
#  ('ingest_state',)]

# %%
tables = [
    "dim_industry",
    "industry_membership",
    "fact_market_cap",
    "fact_stock_prices",
    "ingest_state",
]

for t in tables:
    cnt = client.query(f"SELECT count(*) FROM finance_yf.{t}").result_rows[0][0]
    print(f"{t:25s} {cnt:,}")
# Out:
# dim_industry              290
# industry_membership       2,682
# fact_market_cap           1,467
# fact_stock_prices         622,714
# ingest_state              3,998

# %%
import pandas as pd

pd.DataFrame(
    client.query("""
        SELECT sector_key, industry_key, industry_name, industry_symbol, market_weight
        FROM finance_yf.dim_industry
        ORDER BY sector_key, industry_key
        LIMIT 20
    """).result_rows,
    columns=["sector_key", "industry_key", "industry_name", "industry_symbol", "market_weight"],
)
# Out:
#          sector_key                    industry_key  \
# 0   basic-materials             agricultural-inputs
# 1   basic-materials             agricultural-inputs
# 2   basic-materials                        aluminum
# 3   basic-materials                        aluminum
# 4   basic-materials              building-materials
# 5   basic-materials              building-materials
# 6   basic-materials                       chemicals
# 7   basic-materials                       chemicals
# 8   basic-materials                     coking-coal
# 9   basic-materials                     coking-coal
# 10  basic-materials                          copper
# 11  basic-materials                          copper
# 12  basic-materials                            gold
# 13  basic-materials                            gold
# 14  basic-materials          lumber-wood-production
# 15  basic-materials          lumber-wood-production
# 16  basic-materials  other-industrial-metals-mining
# 17  basic-materials  other-industrial-metals-mining
# 18  basic-materials    other-precious-metals-mining
# 19  basic-materials    other-precious-metals-mining
#
#                        industry_name industry_symbol  market_weight
# 0                Agricultural Inputs     ^YH10110010       0.049670
# 1                Agricultural Inputs     ^YH10110010       0.049670
# 2                           Aluminum     ^YH10150010       0.011416
# 3                           Aluminum     ^YH10150010       0.011416
# 4                 Building Materials     ^YH10120010       0.104736
# 5                 Building Materials     ^YH10120010       0.104736
# 6                          Chemicals     ^YH10130010       0.017231
# 7                          Chemicals     ^YH10130010       0.017231
# 8                        Coking Coal     ^YH10160010       0.004713
# 9                        Coking Coal     ^YH10160010       0.004713
# 10                            Copper     ^YH10150020       0.105296
# 11                            Copper     ^YH10150020       0.105296
# 12                              Gold     ^YH10150040       0.290448
# 13                              Gold     ^YH10150040       0.290448
# 14          Lumber & Wood Production     ^YH10140010       0.009677
# 15          Lumber & Wood Production     ^YH10140010       0.009677
# 16  Other Industrial Metals & Mining     ^YH10150030       0.037636
# 17  Other Industrial Metals & Mining     ^YH10150030       0.037636
# 18    Other Precious Metals & Mining     ^YH10150060       0.014719
# 19    Other Precious Metals & Mining     ^YH10150060       0.014719

# %%
pd.DataFrame(
    client.query("""
        SELECT industry_key, countDistinct(ticker) AS n_stocks
        FROM finance_yf.industry_membership
        GROUP BY industry_key
        ORDER BY n_stocks DESC
        LIMIT 20
    """).result_rows,
    columns=["industry_key", "n_stocks"],
)
# Out:
#                        industry_key  n_stocks
# 0                   medical-devices        50
# 1                    banks-regional        50
# 2                   shell-companies        50
# 3           software-infrastructure        50
# 4                  asset-management        50
# 5              software-application        50
# 6                 aerospace-defense        50
# 7                     biotechnology        50
# 8    specialty-industrial-machinery        50
# 9                    semiconductors        47
# 10                      oil-gas-e-p        46
# 11                  capital-markets        45
# 12  information-technology-services        44
# 13      insurance-property-casualty        44
# 14              specialty-chemicals        42
# 15                oil-gas-midstream        40
# 16                   packaged-foods        39
# 17             diagnostics-research        38
# 18     medical-instruments-supplies        38
# 19                       auto-parts        37
